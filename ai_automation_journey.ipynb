# %% [markdown]
# <a href="https://colab.research.google.com/github/msmaoui101/projetA/blob/main/ai_automation_journey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import requests as rq

API_KEY = "6db63259c32c90216a8d8fe31ec06e80"
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

def get_weather(city):
  params = {
      "q": city,
      "appid": API_KEY,
      "units": "metric"
  }
  response = rq.get(BASE_URL, params=params)
  data = response.json()

  if response.status_code != 200:
    print("X Error:", data.get("message", "Unknown error"))
    return

  temp = data["main"]["temp"]
  wind = data["wind"]["speed"]
  desc = data["weather"][0]["description"]

  print(f" Weather in {city}: {temp}°C, Wind: {wind} m/s")

if __name__ == "__main__":
    if len(sys.argv) < 2:
        print("Usage: python weather.py [city]")
        sys.exit()

    city_name = " ".join(sys.argv[1:])
    get_weather("United kingdom")
# Out:
#  Weather in United kingdom: 10.32°C, Wind: 8.02 m/s
